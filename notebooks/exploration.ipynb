# %% [markdown]
# # Smart Fleet Selection — Data exploration
# Load ship dataset and global params, inspect columns, and run a simple cost/optimization check.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("..").resolve()))

import pandas as pd
from src.data_loader import load_ships, load_global_params, load_config
from src.utils import data_path

# %%
config = load_config("../config/params.yaml")
print("Cargo demand (tonnes/month):", config["cargo_demand_tonnes"])
print("Min avg safety:", config["constraints"]["min_avg_safety_score"])

# %%
# Uncomment when ships.csv is in data/raw/
# df = load_ships(data_path("raw"))
# df.head()
# df["main_engine_fuel_type"].value_counts()
# df["safety_score"].value_counts()

# %%
# Uncomment when global_params.yaml is present
# params = load_global_params(data_path("global_params"))
# list(params.keys())
